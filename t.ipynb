# %%
import schemdraw
import schemdraw.elements as elm

# %%
schemdraw.theme('default')

with schemdraw.Drawing() as diagram:
    elm.Line().up(diagram.unit*.5)
    inicio = elm.SourceSin()
    elm.Line().up(diagram.unit*.5)
    elm.Resistor().right().label('1K')
    elm.MeterA().down()
    diagram.push()
    elm.Diode().down()
    elm.Line().left()
    diagram.pop()
    elm.Line().right()
    elm.MeterV().down()
    elm.Line().left()
    elm.Label().label('Circuito A').at(xy=(3, -0.5))

# %%
schemdraw.theme('default')

with schemdraw.Drawing() as diagram:
    # elm.Line().up(diagram.unit*.5)
    inicio = elm.SourceSin().up()
    # elm.Line().up(diagram.unit*.5)
    elm.Diode().right()
    diagram.push()
    elm.Resistor().down().label('1K')
    elm.Line().left()
    diagram.pop()
    elm.Line().right(diagram.unit*.5)
    elm.Source().down()
    elm.Line().left(diagram.unit*.5)
    elm.Label().label('ocs').at(xy=(4.6, 1.6))
    elm.Label().label('Circuito 1').at(xy=(2.25, -0.5))

# %%
schemdraw.theme('default')

with schemdraw.Drawing() as diagram:
    # elm.Line().up(diagram.unit*.5)
    inicio = elm.SourceSin().up()
    elm.Line().right(diagram.unit*.25)
    elm.Diode().right(diagram.unit*.25)
    elm.Diode().right(diagram.unit*.25)
    elm.Line().right(diagram.unit*.25)
    diagram.push()
    elm.Resistor().down().label('1K')
    elm.Line().left()
    diagram.pop()
    elm.Line().right(diagram.unit*.5)
    elm.Source().down()
    elm.Line().left(diagram.unit*.5)
    elm.Label().label('ocs').at(xy=(4.6, 1.6))
    elm.Label().label('Circuito 2').at(xy=(2.25, -0.5))

# %%
schemdraw.theme('default')

with schemdraw.Drawing() as diagram:
    # elm.Line().up(diagram.unit*.5)
    inicio = elm.SourceSin().up()
    elm.Line().right(diagram.unit*.25)
    elm.Diode().right(diagram.unit*.25)
    # elm.Line().right(diagram.unit*.15)
    elm.Diode().right(diagram.unit*.25).reverse()
    elm.Line().right(diagram.unit*.25)
    diagram.push()
    elm.Resistor().down().label('1K')
    elm.Line().left()
    diagram.pop()
    elm.Line().right(diagram.unit*.5)
    elm.Source().down()
    elm.Line().left(diagram.unit*.5)
    elm.Label().label('ocs').at(xy=(4.6, 1.6))
    elm.Label().label('Circuito 3').at(xy=(2.25, -0.5))

# %%
schemdraw.theme('default')

with schemdraw.Drawing() as diagram:
    # elm.Line().up(diagram.unit*.5)
    inicio = elm.SourceSin().up()
    # elm.Line().up(diagram.unit*.5)
    elm.Diode().right()
    diagram.push()
    elm.Capacitor().down().label('$10 \,\\mu F$')
    elm.Line().left()
    diagram.pop()
    elm.Line().right(diagram.unit*.5)
    diagram.push()
    elm.Resistor().down().label('$1K$')
    elm.Line().left(diagram.unit*.5)
    elm.Line().left()
    diagram.pop()
    elm.Line().right(diagram.unit*.5)
    elm.Source().down()
    elm.Line().left(diagram.unit*.5)
    elm.Label().label('ocs').at(xy=(6.1, 1.6))
    elm.Label().label('Circuito 4').at(xy=(3, -0.5))

# %%
schemdraw.theme('default')

with schemdraw.Drawing() as diagram:
    # elm.Line().up(diagram.unit*.5)
    inicio = elm.SourceSin().up()
    elm.Line().right(diagram.unit*.25)
    diagram.push()
    elm.Line().up(diagram.unit*.15)
    elm.Diode().right(diagram.unit*.5)
    elm.Line().down(diagram.unit*.15)
    diagram.pop()
    elm.Line().down(diagram.unit*.15)
    elm.Diode().right(diagram.unit*.5).reverse()
    elm.Line().up(diagram.unit*.15)
    elm.Line().right(diagram.unit*.25)
    diagram.push()
    elm.Resistor().down().label('1K')
    elm.Line().left()
    diagram.pop()
    elm.Line().right(diagram.unit*.5)
    elm.Source().down()
    elm.Line().left(diagram.unit*.5)
    elm.Label().label('ocs').at(xy=(4.6, 1.6))
    elm.Label().label('Circuito 5').at(xy=(2.25, -0.5))
